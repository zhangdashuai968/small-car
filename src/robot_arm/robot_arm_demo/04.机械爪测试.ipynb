# %%
import math
import numpy as np
from kyle_robot_toolbox.robot_arm.arm4dof_uservo import Arm4DoFUServo

# %%
# 创建机械臂
arm = Arm4DoFUServo(config_folder="./config", \
                    is_init_pose=True)

# %%
# 设置爪子的弧度
arm.set_gripper_angle(math.radians(30), T=0.25, max_power=1000)

# %%
# 设置爪子的弧度
arm.set_gripper_angle(math.radians(0), T=0.25, max_power=1000)

# %%
# 爪子开启
arm.gripper_open()

# %%
# 爪子闭合
arm.gripper_close()
